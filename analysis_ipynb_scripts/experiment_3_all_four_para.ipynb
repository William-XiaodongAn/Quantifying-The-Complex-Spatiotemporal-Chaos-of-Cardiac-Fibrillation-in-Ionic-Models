# %%
import os
import subprocess
import matplotlib.pyplot as plt
import csv
import numpy as np
import random
from scipy.stats import linregress
import math
from datetime import datetime
import dill
import seaborn as sns
import statistics
import sys
import numpy as np
import math
import os
import subprocess
import matplotlib.pyplot as plt
import csv
import numpy as np
import random
from scipy.stats import linregress
import math
from datetime import datetime
import dill
import seaborn as sns
from sklearn.metrics import mutual_info_score
import matplotlib.ticker as mtick
from matplotlib.ticker import MaxNLocator
import ipyparallel as ipp
import pickle

def getDistanceV2(X,d,lag,point1,point2):
    summary = 0
    for i in range(0,d*lag+1,lag):
        summary += (X[point1 + i] - X[point2 + i])**2
    summary = math.sqrt(summary)
    return summary

def simplex_projection(data,d,lag,prediction_steps,neighbor_numbers):
    # data is 1D scalar temporal
    neighbors_distance = []
    neighbors_index = []
    
    for ii,i in enumerate(range(int(len(data) / 2), len(data) - 1 - d * lag  - prediction_steps)):
        neighbors_distance.append(np.full(neighbor_numbers,1e10))
        neighbors_index.append(np.zeros(neighbor_numbers))
        for j in range(int(len(data) / 2) - 1 - d * lag  - prediction_steps):
            distance = getDistanceV2(data,d,lag,i,j)
            if distance < max(neighbors_distance[ii]):
                max_index = np.argmax(neighbors_distance[ii])
                neighbors_distance[ii][max_index] = distance
                neighbors_index[ii][max_index] = j
    
    prediction = []
    observation = []
    
    for step in range(prediction_steps):
        observation.append([])
        prediction.append([])
        for ii,i in enumerate(range(int(len(data) / 2), len(data) - 1 - d * lag  - prediction_steps)):
            observation[step].append(data[int(i + d*lag + step + 1)])
            cur_prediction = 0
            total_weight = 0
            
            for neighbor in neighbors_index[ii]:
                cur_prediction += (1 / getDistanceV2(data,d,lag,i,j)) * data[int(neighbor + d*lag + step + 1)]
                total_weight += (1 / getDistanceV2(data,d,lag,i,j))
                
            cur_prediction /= total_weight
            prediction[step].append(cur_prediction)
    return prediction,observation
def avg(lya):
    result = []
    err = []
    
    for j in range(len(lya[0][0])):
        result.append([])
        err.append([])
        value = []      
        for i in range(len(lya)):
            if lya[i][0][j]!= float("inf"):
                value.append(lya[i][0][j])

        result[j] = sum(value)/len(value)
        err[j] = np.std(value)       
    return result,err

def avg_repeat(lya):
    result = []
    err = []
    
    for j in range(len(lya[0][0])):
        result.append([])
        err.append([])
        value = []   
        for k in range(len(lya)):
            for i in range(len(lya[0])):
                if lya[k][i][j][0]!= float("inf"):
                    value.append(lya[k][i][j][0])

        result[j] = sum(value)/len(value)
        err[j] = np.std(value)       
    return result,err

def avg_repeat2(lya):
    result = []
    err = []
    
    for j in range(len(lya[0][0][0])):
        result.append([])
        err.append([])
        value = []   
        for k in range(len(lya)):
            for i in range(len(lya[0])):
                if np.isnan(lya[k][i][0][j]) == False and lya[k][i][0][j]!= float("inf"):
                    value.append(lya[k][i][0][j])

        result[j] = sum(value)/len(value)
        err[j] = np.std(value)       
    return result,err

def avg_taupw(lya):
    result = []
    err = []
    
    for j in range(len(lya[0])):
        result.append([])
        err.append([])
        value = []      
        for i in range(len(lya)):
            if lya[i][j][0]!= float("inf"):
                value.append(lya[i][j][0])

        result[j] = sum(value)/len(value)
        err[j] = np.std(value)       
    return result,err
def linear_interpolation(y0,y1,x0,x1,x):
    
    return (y0 * (x1-x) + y1 * (x-x0)) / (x1-x0)
def get_APD_and_voltage_new(path,threshhold,dt):
    
    number_of_points = 0
    end_of_first_dt = False
    data = []
    
    with open(path) as csv_file: # totally 501 points
        csv_reader = csv.reader(csv_file, delimiter=',')
        
        for row in csv_reader:
            for i in range(len(row)):
                for j in row[i]:
                    if j == ';':
                        row[i] = row[i].replace(';', '')
                        if end_of_first_dt == False:
                            end_of_first_dt = True
                            number_of_points = i
                if row[i] != '':           
                    data.append(float(row[i]))                
    if (len(data)/number_of_points).is_integer():
        rows, cols=number_of_points,int(len(data)/number_of_points)
    else:
        print('error! non-integar time steps')     

    voltage = np.zeros([rows,cols])

    for i in range(rows):
        for j in range(cols):

            voltage[i][j] = data[j * rows +  i]
         
    APD = []
    # linear interpolation 
    APD_start_error = -100
    APD_end_error = -100    


    for i in range(number_of_points):
        APD.append([])
        
        APD_value = 0
        start_apd = False
        
        for j in range(len(voltage[0])):


            if j != 0 and start_apd == False and voltage[i][j] > threshhold   and j+1 < len(voltage[0]) and voltage[i][j+1] > threshhold:
                start_apd = True
                APD_start_error = linear_interpolation(1,0,voltage[i][j],voltage[i][j-1],threshhold)
                APD_start_error = 1 - APD_start_error

            if start_apd == True and voltage[i][j] <= threshhold and j+1 < len(voltage[0]) and voltage[i][j+1] <= threshhold: 
                start_apd = False
                APD_end_error = linear_interpolation(0,-1,voltage[i][j],voltage[i][j-1],threshhold)
                
                # linear interpolation 
                APD_value += (APD_start_error + APD_end_error) * dt
 
                
                APD[i].append(APD_value)
            
                APD_value = 0
                APD_start_error = -100
                APD_end_error = -100 
                
            if start_apd == True:
                APD_value += dt
        
        # trim first incomplete APD
        if voltage[i][1] > threshhold and voltage[i][2] > threshhold:
            APD[i].pop(0)
    
    return APD,voltage
def get_APD_and_voltage_uvw(path,threshhold,dt,scale = False):
    
    number_of_points = 0
    end_of_first_dt = False
    
    data = []
    with open(path) as csv_file: # totally 501 points
        csv_reader = csv.reader(csv_file, delimiter=',')
        
        for row in csv_reader:
            for i in range(len(row)):
                for j in row[i]:
                    if j == ';':
                        row[i] = row[i].replace(';', '')
                        if end_of_first_dt == False:
                            end_of_first_dt = True
                            number_of_points = i
                        
                if row[i] != '' and i%4 != 0: 
                    data.append(float(row[i]))    
    max_value = max(data)
    min_value = min(data)
    if scale == True:
        for i in range(len(data)):
            data[i] = (data[i] - min_value) / (max_value - min_value)

    # if we input whole texture
    if (number_of_points * 3 / 4).is_integer():
        number_of_points = int( number_of_points * 3 / 4)
    else:
        print('error! non-integar number of points')
    # if we input whole texture
    
    if (len(data)/number_of_points).is_integer():
        rows, cols=number_of_points,int(len(data)/number_of_points)
    else:
        print('error! non-integar time steps',len(data),number_of_points) 
        
    voltage = np.zeros([rows,cols])

    for i in range(rows):
        for j in range(cols):

            voltage[i][j] = data[j * rows +  i]

    print(number_of_points)
    
    APD = []
    # linear interpolation 
    APD_start_error = -100
    APD_end_error = -100    


    for i in range(number_of_points):
        APD.append([])
        
        APD_value = 0
        start_apd = False

        if i % 3 != 2 :
        
            for j in range(len(voltage[0])):
    
    
                if j != 0 and start_apd == False and voltage[i][j] > threshhold   and j+1 < len(voltage[0]) and voltage[i][j+1] > threshhold:
                    start_apd = True
                    
                    if j%4 == 0 and abs(voltage[i][j] - voltage[i][j-1]) < 1e-9:
                        print(i,j)
                        print( voltage[i])
                        sys.exit()
                    APD_start_error = linear_interpolation(1,0,voltage[i][j],voltage[i][j-1],threshhold)
                    APD_start_error = 1 - APD_start_error
    
                if start_apd == True and voltage[i][j] < threshhold and j+1 < len(voltage[0]) and voltage[i][j+1] < threshhold: 
                    start_apd = False
                    APD_end_error = linear_interpolation(0,-1,voltage[i][j],voltage[i][j-1],threshhold)
                    
                    # linear interpolation 
                    APD_value += (APD_start_error + APD_end_error) * dt
     
                    
                    APD[i].append(APD_value)
                
                    APD_value = 0
                    APD_start_error = -100
                    APD_end_error = -100 
                    
                if start_apd == True:
                    APD_value += dt
            
            # trim first incomplete APD
            if voltage[i][1] > threshhold and voltage[i][2] > threshhold and len(APD[i]) > 0:
                APD[i].pop(0)
            
    APD_u = []
    APD_v = []
    #APD_w = []
    voltage_u = []
    voltage_v = []
    voltage_w = []

    for i in range(len(APD)):
        if (i+1) % 3 == 1:
            APD_u.append(APD[i])
            voltage_u.append(voltage[i])
        if (i+1) % 3 == 2:
            APD_v.append(APD[i])
            voltage_v.append(voltage[i])
        if (i+1) % 3 == 0:
            #APD_w.append(APD[i])
            voltage_w.append(voltage[i])

    APD_uvw = [APD_u,APD_v]#,APD_w]
    voltage_uvw = [voltage_u,voltage_v,voltage_w]
    
    return APD_uvw,voltage_uvw
    



def embed_data(data,m,tau=1):
    
    embedded_data = np.zeros([len(data) - m*tau,m])
    
    for i in range(len(data) - m*tau):
        for j in range(m):
            embedded_data[i][j] = data[i + j*tau]
    return embedded_data


def euclidian_distance(X,Y):
    dis = 0
    for i in range(len(X)):
        dis += (X[i] - Y[i])**2
    return np.sqrt(dis)

def magnitude(X): 
    magnitude = 0
    for i in range(len(X)):
        magnitude += X[i]**2
    return np.sqrt(magnitude)

def angle(X,Y):
    
    return math.acos(round( np.dot(X, Y) / ( magnitude(X) * magnitude(Y) )  , 7) )

def find_nearest_neighbor(embedded_data,cur_point,epsilon,theta,boundary):
    
    length = len(embedded_data)
    dim = len(embedded_data[0])
    
    dis = 1e8
    nearest_Y_index = 1e8
    X = embedded_data[cur_point]
    
    for i in range(int(length - boundary)):
        Y = embedded_data[i]
        if i != cur_point and euclidian_distance(X,Y) < dis and angle(X,Y) < theta:
            dis = euclidian_distance(X,Y)
            nearest_Y_index = i
    
    if dis < epsilon:
        return dis,nearest_Y_index
    else:
        print("cannot find neighbor for point ", cur_point, ',dis = ', dis)
        return False
    
def find_L_and_evolve_point(embedded_data,cur_point,epsilon,theta,boundary):
    
    L0 = 0
    L0_prime = 0
    
    length = len(embedded_data)
    dim = len(embedded_data[0])
    
    x = embedded_data[cur_point]
    
    result = find_nearest_neighbor(embedded_data,cur_point,epsilon,theta,boundary)
    
    while result == False:
        return False

    
    neighbor_point = result[1]
    z = embedded_data[neighbor_point]

    
    L0 =  result[0]
    L0_prime = result[0]
    
    step = 0
    while L0_prime < epsilon and (cur_point + step) < length and (neighbor_point + step) < length:

        
        '''
        if cur_point + step >= length:
            if cur_point < (3/4 * length):
                print("cur_point + step >= length",embedded_data[cur_point + step] , embedded_data[neighbor_point + step],cur_point )
            return False
        '''
        x = embedded_data[cur_point + step]
        '''
        if neighbor_point + step >= length:
            print("neighbor_point + step >= length",embedded_data[cur_point + step] , embedded_data[neighbor_point + step],neighbor_point )
            return False
        '''
        z = embedded_data[neighbor_point + step]
        
        L0_prime = euclidian_distance(x,z)
        step += 1
        
    return np.log(L0_prime / L0) / np.log(2) , cur_point + step

    
def wolf_lya_exp(embedded_data,epsilon = 0.1,start_point = 'middle',theta = np.pi / 9,boundary = 1500):
    
    if start_point == 'middle':
        start_point = int(len(embedded_data) / 2) - boundary
    
    cur_point = start_point
    log_sum = 0
    
    while cur_point < len(embedded_data):
        
        result = find_L_and_evolve_point(embedded_data,cur_point,epsilon,theta,boundary)

        if result != False:     
            log_sum += result[0]
            cur_point = result[1]        
        
        if cur_point == start_point:
            start_point += 1
            cur_point = start_point           
            continue
        
        if result == False:
            break

        

    return log_sum /  (cur_point - start_point)


#dill.dump_session('notebook_env.db')
#dill.load_session('notebook_env.db')

def run_cmd(command): # cmd /k command
    
    
    
    command ='cmd /k \"' +  command + '\"'

    try:
        os.system(command)
        result = subprocess.check_output(command, shell=True, text=True)
        #print(result)        
        
    except:
        print('error os cmd')
        
def getDistance(X,i,d,k,h):
    summary = 0
    for j in range(i-1,i+d-1):
        summary += (X[j][k] - X[j][h])**2
    summary = math.sqrt(summary)
    return summary
def findPairs(X,i,d,k,h,e):
    if k == h:
        return False
    summary = getDistance(X,i,d,k,h)
    if summary < e and summary > 0:
        #print(summary)
        return True
    else:
        return False
def findLyp(X,d,e):
    lyp = 0
    Np = 0
    m = X.shape[0]
    L = X.shape[1]
    for jj in range(0,m-d):
        #print(jj)
        for kk in range(L):
            for hh in range(kk + 1,L):
                if findPairs(X,jj+1,d,kk,hh,e) == True and getDistance(X,jj+2,d,kk,hh) > 0:
                    Np += 1
                    lyp += math.log(getDistance(X,jj+2,d,kk,hh)/getDistance(X,jj+1,d,kk,hh))
                    #if (abs(lyp) > 1000):
                        #print(lyp,getDistance(jj+2,d,kk,hh),getDistance(jj+1,d,kk,hh),jj,kk,hh)

    if Np == 0:
        print('error')
        return
    lyp = lyp/Np
    #print("lyapunov exp is:",lyp,"\nnumber of pairs found:",Np)
    return lyp

def linear_interpolation(y0,y1,x0,x1,x):
    return (y0 * (x1-x) + y1 * (x-x0)) / (x1-x0)

def get_APD_and_voltage(tau_pw,tau_d,number_of_points,dt = 4,noise = False, noise_value_percentage = 0.1):
    
    tau_pw = str(tau_pw)
    tau_d = str(tau_d)
    data = []

    with open('tau_pw_' + tau_pw + '_tau_d_' + tau_d + '_spatial.csv') as csv_file: # totally 501 points
        csv_reader = csv.reader(csv_file, delimiter='.')
        for row in csv_reader:
            data.append(float(row[0] + '.' + row[1][:-1]))
            for i in range(1,len(row) - 1):
                for j in row[i + 1]:
                    if j == ';':
                        row[i + 1] = row[i + 1].replace(';', '')
                        
                if i == len(row) - 2:    
                    data.append(float(row[i][-1] + '.' + row[i + 1][:]))                    
                
                else:
                    data.append(float(row[i][-1] + '.' + row[i + 1][:-1]))
                    #r_03999.append(float(row[i]))                
    
    rows, cols=number_of_points,int(len(data)/number_of_points)
    voltage = np.zeros([rows,cols])

    for i in range(rows):
        for j in range(cols):

            voltage[i][j] = data[j * rows +  i]
         
    APD = []
    # linear interpolation 
    APD_start_error = -100
    APD_end_error = -100    


    for i in range(number_of_points):
        APD.append([])
        
        APD_value = 0
        start_apd = False
        
        for j in range(len(voltage[0])):


            if j != 0 and start_apd == False and voltage[i][j] > 0.3   and j+1 < len(voltage[0]) and voltage[i][j+1] > 0.3:
                start_apd = True
                APD_start_error = linear_interpolation(1,0,voltage[i][j],voltage[i][j-1],0.3)
                APD_start_error = 1 - APD_start_error

            if start_apd == True and voltage[i][j] <= 0.3 and j+1 < len(voltage[0]) and voltage[i][j+1] <= 0.3: 
                start_apd = False
                APD_end_error = linear_interpolation(0,-1,voltage[i][j],voltage[i][j-1],0.3)
                
                # linear interpolation 
                APD_value += (APD_start_error + APD_end_error) * dt
 
                
                APD[i].append(APD_value)
            
                APD_value = 0
                APD_start_error = -100
                APD_end_error = -100 
                
            if start_apd == True:
                APD_value += dt
        
        # trim first incomplete APD
        if voltage[i][1] > 0.3 and voltage[i][2] > 0.3:
            APD[i].pop(0)

        # add some percentage noise to APD data
        if noise == True:
            APD_averaged_for_i = sum(APD[i]) / len(APD[i])
            for APD_index_i in range(len(APD[i])):
                APD[i][APD_index_i] += 2 * np.round(random.uniform(-APD_averaged_for_i * noise_value_percentage, APD_averaged_for_i * noise_value_percentage) / 2)
                if APD[i][APD_index_i] < 0:
                    print("noise too large",APD[i][APD_index_i])
                    APD[i][APD_index_i] = 0
    
    return APD,voltage

def find_temp_lya_exp_growth_in_lyap_file(file_name,tisean_parameter):
    
    delta_s = []

        
    with open(file_name) as csv_file:
        csv_reader = csv.reader(csv_file)
        cur_eps_dim = False        
        for row in csv_reader:
            if row == [tisean_parameter]:
                cur_eps_dim = True
                continue
            
            if cur_eps_dim == True:
                
                if row == []:
                    break


                num = ''
                check_time = 0
                for i in row[0]:
                    if i == ' ':
                        check_time += 1
                        continue
                    if check_time == 1:
                        num += i
                num = float(num)
                delta_s.append(num) 
            else:
                continue
    return delta_s

def is_monotonic(arr):
    unique_elements = set(arr)
    increasing = sorted(arr) == arr or sorted(arr, reverse=True) == arr
    return increasing


def get_temporal_lya_exp(APD,how_many_temporal_lya_want,tau_pw,tau_d,r = 10, R = 50,s = 50,tisean_parameter = '#epsilon= 5.000000e+001  dim= 4',path = "D://Downloads/TISEAN_9_17"):
    
    tau_pw = str(tau_pw)
    tau_d = str(tau_d)
    
    temporal_lya_exp_list = [] # (lya exp)
    temporal_lya_exp_list_index = []
    


    point_index = list(range(len(APD)))

    random.shuffle(point_index)
    
    os.chdir(path)
    
    for i in point_index:

        # output the APD to dat file
        name = 'tau_pw_' + tau_pw + '_tau_d_' + tau_d + "_p" + str(i) + ".dat"
        f=open(name,"w")
        for line in APD[i]:
            f.write(str(line)+"\n")
        f.close()              


        # run tisean
        
        #if os.path.isfile(name + ".lyap") != True:
        
        command = 'lyap_k ' + name + ' -M4 -m3 -d1 -s' + str(s) + ' -r' + str(r) + ' -R' + str(R) +' -o'
        run_cmd(command)

        # examine if we have linear region for this point
        delta_s = find_temp_lya_exp_growth_in_lyap_file(name + ".lyap" , tisean_parameter)
        if delta_s != []:
            for linear_x_range in range(7,4,-1):
                if (is_monotonic(delta_s[:linear_x_range]) == True):
                    if delta_s[linear_x_range-1] > delta_s[0]:
                        if abs(min(delta_s[linear_x_range-1:]) - delta_s[linear_x_range-1]) < 0.1:
                            time = list(range(len(delta_s)))  

                            temporal_lya_exp_list.append(linregress(time[:linear_x_range],delta_s[:linear_x_range])[0])
                            temporal_lya_exp_list_index.append(i)
                          
                            break
        
                    elif delta_s[linear_x_range-1] < delta_s[0]:
                        if abs(max(delta_s[linear_x_range-1:]) - delta_s[linear_x_range-1]) < 0.1:
                            time = list(range(len(delta_s)))  

                            temporal_lya_exp_list.append(linregress(time[:linear_x_range],delta_s[:linear_x_range])[0])
                            temporal_lya_exp_list_index.append(i)  

                            break
                
                if len(temporal_lya_exp_list) >= how_many_temporal_lya_want:
                    return temporal_lya_exp_list,temporal_lya_exp_list_index            
                        
    return temporal_lya_exp_list,temporal_lya_exp_list_index 

def get_spatial_lya_exp(APD,number_of_points_used,spatial_dim = 4,spatial_diff = 3,repeat_time = 10):
    
    lyp_exp_list = []
    
    for repeat_time_i in range(repeat_time):
    
        shuffled_partial_APD = random.sample(APD, number_of_points_used)


        length = number_of_points_used

        min_minn = 3

        minn = 1e5
        for i in range(number_of_points_used):
            if len(shuffled_partial_APD[i]) < minn and len(shuffled_partial_APD[i]) > min_minn:
                minn = len(shuffled_partial_APD[i]) 
            if len(shuffled_partial_APD[i]) <= min_minn:
                length -= 1
                #print('zero apd detected')


        APD_consist = np.full((minn-1,length),-100) # [1:14]
        for i in range(length):
            for j in range(minn-1):
                if len(shuffled_partial_APD[i]) > min_minn:
                    APD_consist[j][i] = shuffled_partial_APD[i][j+1]
        lyp_exp = findLyp(APD_consist,spatial_dim,spatial_diff)     #  # taud = 0.41 
        
        if lyp_exp is not None:
            lyp_exp_list.append(lyp_exp)

        #print(lyp_exp,'minn',minn,'length',length,repeat_time_i,'\n')
    
    lyp_exp_averaged = sum(lyp_exp_list) / len(lyp_exp_list)      
    
    return lyp_exp_averaged,lyp_exp_list

#计算GP算法的嵌入维数(假近邻算法)
def get_m(imf, tau):
    N=len(imf)
    if (len(imf) != N):
        print('请输入指定的数据长度！')  # N为指定数据长度
        return 0, 0
    elif (isinstance(imf, np.ndarray) != True):
        print('数据格式错误！')
        return 0, 0
    else:
        m_max = 10
        P_m_all = []  # m_max-1个假近邻点百分率
        for m in range(1, m_max + 1):
            print(m)
            
            i_num = N - (m - 1) * tau
            kj_m = np.zeros((i_num, m))  # m维重构相空间
            for i in range(i_num):
                for j in range(m):
                    kj_m[i][j] = imf[i + j * tau]
            if (m > 1):
                index = np.argsort(Dist_m)
                a_m = 0  # 最近邻点数
                for i in range(i_num):
                    temp = 0
                    for h in range(i_num):
                        temp = index[i][h]
                        if (Dist_m[i][temp] > 0):
                            break
                    D = np.linalg.norm(kj_m[i] - kj_m[temp])
                    D = np.sqrt((D * D) / (Dist_m[i][temp] * Dist_m[i][temp]) - 1)
                    if (D > 10):
                        a_m += 1
                P_m_all.append(a_m / i_num)
            i_num_m = i_num - tau
            Dist_m = np.zeros((i_num_m, i_num_m))  # 两向量之间的距离
            for i in range(i_num_m):
                for k in range(i_num_m):
                    Dist_m[i][k] = np.linalg.norm(kj_m[i] - kj_m[k])
        P_m_all = np.array(P_m_all)
        m_all = np.arange(1, m_max)
        return m_all, P_m_all
        
def get_tau(data,tau_start = 1,tau_end = 10,num_of_bin = 1000,lower_bound = 0.,upper_bound = 1.):

    mutual_info_list = []
    
    for tau in range(tau_start,tau_end):
        
        X = data
        Y = np.roll(X, tau)
        
        X_binned = np.digitize(X, bins=np.linspace(lower_bound, upper_bound, num_of_bin))
        Y_binned = np.digitize(Y, bins=np.linspace(lower_bound, upper_bound, num_of_bin))        
        
        mutual_info = mutual_info_score(X_binned, Y_binned)
        mutual_info_list.append(mutual_info)
    return mutual_info_list

  
def get_restitution2(arr):
    APD = []
    for i in range(len(arr)):
        APD.append([])

        APD_value = 0
        start_apd = False
        for j in range(len(arr[0])):


            if start_apd == False and arr[i][j] > 0.3:
                start_apd = True
                if j == 0:
                    APD_start_error = 0
                else:
                    APD_start_error = linear_interpolation(1,0,arr[i][j],arr[i][j-1],0.3)
                    APD_start_error = 1 - APD_start_error
                
            if start_apd == True and arr[i][j] <= 0.3: 
                start_apd = False
                APD_end_error = linear_interpolation(0,-1,arr[i][j],arr[i][j-1],0.3)
                
                APD_value += (APD_start_error + APD_end_error) * 4                
                APD[i].append(APD_value)
                APD_value = 0
                APD_start_error = -100
                APD_end_error = -100 
            if start_apd == True:
                APD_value += 4

    # the first DI is either not-complete or missing, so do not use it in restitutional curve

    DI = []            
    for i in range(len(arr)):
        DI.append([])

        DI_value = 0
        start_di = False






        for j in range(len(arr[0])):


            if start_di == False and arr[i][j] <= 0.3:
                start_di = True
                DI_start_error = linear_interpolation(0,-1,arr[i][j],arr[i][j-1],0.3)
                
            if start_di == True and arr[i][j] > 0.3: 
                start_di = False
                DI_end_error = linear_interpolation(1,0,arr[i][j],arr[i][j-1],0.3)
                DI_end_error = 1 - DI_end_error
                DI_value += (DI_start_error + DI_end_error) * 4                 
                DI[i].append(DI_value)
                DI_value = 0
                DI_start_error = -100
                DI_end_error = -100 
            if start_di == True:
                DI_value += 4

        if arr[i][-1] > 0.3:

            del DI[i][-1]   

    X1 = []
    X2 = [] 

    for i in range(len(arr)):
        if arr[i][0] > 0.3:
            for j in range(2,len(APD[i])):
                X1.append(DI[i][j-1])
                X2.append(APD[i][j])
        else:
            for j in range(2,len(APD[i])):
                X1.append(DI[i][j])
                X2.append(APD[i][j])            
    return X2,X1
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.patches import Rectangle
from matplotlib.legend_handler import HandlerBase

def plot_custom_legend():
    # --- Handler for uvw (line + error bar + caps + marker) ---
    class HandlerErrorbarWithCap(HandlerBase):
        def create_artists(self, legend, orig_handle,
                           xdescent, ydescent, width, height, fontsize, trans):
            line, err = orig_handle 
            center_x = xdescent + width / 2 - 1
            center_y = ydescent + height / 2 # try 0.02–0.05
    
    
            # Full error bar height
            err_span = height * 1.2
            err_ymin = center_y - err_span / 2
            err_ymax = center_y + err_span / 2
    
            # Error bar line
            err_art = Line2D([center_x, center_x],
                             [err_ymin, err_ymax],
                             color=err.get_color(),
                             linewidth=err.get_linewidth(),
                             transform=trans)
    
            # Caps
            cap_len = 6 /30 * fontsize  # simulate capsize=6
            cap_top = Line2D([center_x - cap_len , center_x + cap_len ],
                             [err_ymax, err_ymax],
                             color=err.get_color(),
                             linewidth=err.get_linewidth(),
                             transform=trans)
            cap_bottom = Line2D([center_x - cap_len , center_x + cap_len ],
                                [err_ymin, err_ymin],
                                color=err.get_color(),
                                linewidth=err.get_linewidth(),
                                transform=trans)
    
            # Horizontal line
            line_art = Line2D([xdescent, xdescent + width],
                              [center_y, center_y],
                              linestyle=line.get_linestyle(),
                              color=line.get_color(),
                              linewidth=line.get_linewidth(),
                              transform=trans)
    
            # Marker in center
            marker = Line2D([center_x],
                            [center_y],
                            linestyle='None',
                            marker=line.get_marker(),
                            markersize=6,
                            markerfacecolor='none',
                            markeredgecolor=line.get_color(),
                            transform=trans)
    
            return [line_art, err_art, cap_top, cap_bottom, marker]
    
    # --- Handler for APD (line + shaded region + marker) ---
    class HandlerShadedLine(HandlerBase):
        def create_artists(self, legend, orig_handle,
                           xdescent, ydescent, width, height, fontsize, trans):
            line, patch = orig_handle 
            center_y = ydescent + height / 2
            center_x = xdescent + width / 2 - 1
    
            # Shaded region
            shade = Rectangle((xdescent, ydescent), width, height,
                              facecolor=patch.get_facecolor(),
                              alpha=patch.get_alpha(),
                              edgecolor='none', transform=trans)
    
            # Dashed line
            line_segment = Line2D([xdescent, xdescent + width],
                                  [center_y, center_y],
                                  linestyle=line.get_linestyle(),
                                  color=line.get_color(),
                                  linewidth=line.get_linewidth(),
                                  transform=trans)
    
            # Marker in center
            marker = Line2D([center_x],
                            [center_y],
                            linestyle='None',
                            marker=line.get_marker(),
                            markersize=6,
                            markerfacecolor='none',
                            markeredgecolor=line.get_color(),
                            transform=trans)
    
            return [shade, line_segment, marker]
    
    # --- Define legend handles and labels ---
    uvw_line = Line2D([0], [0], color='tab:blue', linestyle=':', marker='o',markerfacecolor='none')
    uvw_err = Line2D([0], [0], color='tab:blue', linestyle='-', linewidth=1)
    
    apd_temp_line = Line2D([0], [0], color='tab:orange', linestyle=':', marker='^')
    apd_spat_line = Line2D([0], [0], color='tab:green', linestyle=':', marker='s')
    
    legend_handles = [
        (uvw_line),
        (apd_temp_line, Rectangle((0, 0), 1, 1, facecolor='tab:orange', alpha=0.25)),
        (apd_spat_line, Rectangle((0, 0), 1, 1, facecolor='tab:green', alpha=0.25))
    ]
    
    legend_labels = [
        r"Ground Truth",
        r"$APD$ (temporal)",
        r"$APD$ (spatial)"
    ]
    
    handler_map = {
        tuple: HandlerShadedLine(),
        (uvw_line, uvw_err): HandlerErrorbarWithCap()
    }
    
    
    legend = plt.legend(legend_handles, legend_labels,
               handler_map=handler_map, loc='upper right', fontsize=11)
    return legend

m_u = 4
m_APD = 4

epsilon_uvw = 0.8
epsilon_uv = 0.4
epsilon_APD = 120

# %%
def get_APD_and_voltage_uvw(path,threshhold,dt,dt_multiplier = 1, scale = False):
    
    dt = dt * dt_multiplier
    
    number_of_points = 0
    end_of_first_dt = False
    
    data = []
    with open(path) as csv_file: # totally 501 points
        csv_reader = csv.reader(csv_file, delimiter=',')
        
        for row in csv_reader:
            for i in range(len(row)):
                for j in row[i]:
                    if j == ';':
                        row[i] = row[i].replace(';', '')
                        if end_of_first_dt == False:
                            end_of_first_dt = True
                            number_of_points = i
                        
                if row[i] != '' and i%4 != 0: 
                    data.append(float(row[i]))    
    max_value = max(data)
    min_value = min(data)
    if scale == True:
        for i in range(len(data)):
            data[i] = (data[i] - min_value) / (max_value - min_value)

    # if we input whole texture
    if (number_of_points * 3 / 4).is_integer():
        number_of_points = int( number_of_points * 3 / 4)
    else:
        print('error! non-integar number of points')
    # if we input whole texture
    
    if (len(data)/number_of_points).is_integer():
        rows, cols=number_of_points,int(len(data)/number_of_points)
    else:
        print('error! non-integar time steps',len(data),number_of_points) 
        
    ####### emulate dt_multiplier*dt in voltage by skipping (dt_multiplier-1) points in voltage
    
    # rows: number of points in space * 4
    # cols: number of time steps, each point has same number of time steps
    #voltage = np.zeros([rows,cols])

    #for i in range(rows):
    #    for j in range(cols):

    #        voltage[i][j] = data[j * rows +  i]
            
    new_cols = cols // dt_multiplier
    voltage = np.zeros([rows, new_cols])

    for i in range(rows):
        for j in range(new_cols):
            # j * dt_multiplier jumps ahead in time
            voltage[i][j] = data[(j * dt_multiplier) * rows + i]
    ####### emulate dt_multiplier*dt in voltage by skipping (dt_multiplier-1) points in voltage

    print(number_of_points)
    
    APD = []
    # linear interpolation 
    APD_start_error = -100
    APD_end_error = -100    


    for i in range(number_of_points):
        APD.append([])
        
        APD_value = 0
        start_apd = False

        if i % 3 == 0 :
        
            for j in range(len(voltage[0])):
    
    
                if j != 0 and start_apd == False and voltage[i][j] > threshhold   and j+1 < len(voltage[0]) and voltage[i][j+1] > threshhold:
                    start_apd = True
                    
                    if j%4 == 0 and abs(voltage[i][j] - voltage[i][j-1]) < 1e-9:
                        print(i,j)
                        print( voltage[i])
                        sys.exit()
                    APD_start_error = linear_interpolation(1,0,voltage[i][j],voltage[i][j-1],threshhold)
                    APD_start_error = 1 - APD_start_error
    
                if start_apd == True and voltage[i][j] < threshhold and j+1 < len(voltage[0]) and voltage[i][j+1] < threshhold: 
                    start_apd = False
                    APD_end_error = linear_interpolation(0,-1,voltage[i][j],voltage[i][j-1],threshhold)
                    
                    # linear interpolation 
                    APD_value += (APD_start_error + APD_end_error) * dt
     
                    
                    APD[i].append(APD_value)
                
                    APD_value = 0
                    APD_start_error = -100
                    APD_end_error = -100 
                    
                if start_apd == True:
                    APD_value += dt
            
            # trim first incomplete APD
            if voltage[i][1] > threshhold and voltage[i][2] > threshhold and len(APD[i]) > 0:
                APD[i].pop(0)
            
    APD_u = []
    #APD_v = []
    #APD_w = []
    voltage_u = []
    voltage_v = []
    voltage_w = []

    for i in range(len(APD)):
        if (i+1) % 3 == 1:
            APD_u.append(APD[i])
            voltage_u.append(voltage[i])
        #if (i+1) % 3 == 2:
            #APD_v.append(APD[i])
            #voltage_v.append(voltage[i])
        #if (i+1) % 3 == 0:
            #APD_w.append(APD[i])
            #voltage_w.append(voltage[i])

    APD_uvw = [APD_u,[]]#,APD_w]
    voltage_uvw = [voltage_u,voltage_v,voltage_w]
    
    return APD_uvw,voltage_uvw

# %%
def getAPD(para_name,para_list,dt_multiplier = 1):
    result_4_uvw_list = []
    
    result_4_tau_pw_list = [350]
    result_4_repeat_list = ['',' (1)',' (2)',' (3)',' (4)']
    result_4_tau_r_list = para_list
    result_4_APD_list = np.empty((len(result_4_repeat_list), len(result_4_tau_r_list), len(result_4_tau_pw_list)), dtype=object)  # make it a numpy array so lateron dont need append
    result_4_uvw_list = np.empty((len(result_4_repeat_list), len(result_4_tau_r_list), len(result_4_tau_pw_list)), dtype=object)  # make it a numpy array so lateron dont need append
    for repeat_index,repeat in enumerate(result_4_repeat_list):
        print(repeat_index,para_name)
        
        for tau_r_index,tau_r in enumerate(result_4_tau_r_list):

            for tau_pw_index, tau_pw in enumerate(result_4_tau_pw_list):
                tau_pw = str(tau_pw)
                tau_r = str(tau_r)

                path = "D://result/tau_pw_"+ tau_pw + "_"+ para_name + "_" + tau_r + "_spatial_20e4_32e4_8_8_APD_step_4" + repeat + ".csv"
                
                # check if path there:
                if os.path.isfile(path) != True:
                    path = "C://Users/xan37/Downloads/results/tau_pw_"+ tau_pw + "_"+ para_name + "_" + tau_r + "_spatial_20e4_32e4_8_8_APD_step_4" + repeat + ".csv"

                APD,V = get_APD_and_voltage_uvw(path,0.3,4,dt_multiplier)

                result_4_uvw_list[repeat_index, tau_r_index, tau_pw_index] = V
                result_4_APD_list[repeat_index, tau_r_index, tau_pw_index] = APD[0]
    return result_4_APD_list

dt_multiplier_lst = [1,7,8,9]
tau_r_list = [33.5,33.6,33.7,33.8,33.9,34,34.1,34.2,34.3,34.4,34.5]          
tau_si_list = [26.45,26.5,26.55,26.6 ,26.65 ,26.7 ,26.75,26.8,26.85,26.9,26.95]
tau_0_list = [7.2,7.4,7.6,7.8,8,8.2,8.4,8.6,8.8,9,9.2,9.4]
with open('result_tau_d_list_non_transition.pkl', 'rb') as f:
    tau_d_list_non_transition = pickle.load(f)

with open('result_tau_d_list_transition.pkl', 'rb') as f:
    tau_d_list_transition = pickle.load(f)   
tau_d_list = tau_d_list_non_transition[:4] + tau_d_list_transition + tau_d_list_non_transition[4:]



order = [['tau_r',tau_r_list],['tau_si',tau_si_list],['tau_0',tau_0_list],['tau_d',tau_d_list]]

for dt_multiplier in dt_multiplier_lst:
    for para_pair in order:
        para_name = para_pair[0]
        para_list = para_pair[1]
        APDs=getAPD(para_name, para_list, dt_multiplier)
        # save APDs as pickle file
        file_name = 'APDs_' + para_name + '_dt_multiplier_' + str(dt_multiplier) + '.pkl'
        # if file_name already exists, skip
        if os.path.isfile(file_name) == True:
            print(file_name + ' already exists, skip')
            continue
        with open(file_name, 'wb') as f:
            pickle.dump(APDs, f)
# Out:
# 0 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 1 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 2 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 3 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 4 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 0 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 1 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 2 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 3 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 4 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 0 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 1 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 2 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 3 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 4 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 0 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 1 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 2 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 3 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 4 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 0 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 1 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 2 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 3 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 4 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 0 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 1 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 2 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 3 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 4 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 0 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 1 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 2 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 3 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 4 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 0 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 1 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 2 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 3 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 4 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 0 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 1 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 2 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 3 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 4 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 0 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 1 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 2 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 3 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 4 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 0 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 1 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 2 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 3 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 4 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 0 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 1 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 2 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 3 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 4 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 0 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 1 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 2 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 3 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 4 tau_r
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 0 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 1 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 2 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 3 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 4 tau_si
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 0 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 1 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 2 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 3 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 4 tau_0
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 0 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 1 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 2 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 3 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 4 tau_d
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192

# %%
def f_exp_3(APDs,result_4_tau_r_list,result_uvw,dt_multiplier,exp_lib):
    result_4_tau_pw_list = [350]
    result_4_repeat_list = ['',' (1)',' (2)',' (3)',' (4)']
    
    ####################
    # exp 3 for different dt_multiplier
    ####################   
    num_of_point = 64//5 + 1 # range(0,64,5)
    
    if dt_multiplier in exp_lib:
        return 
    print(dt_multiplier)
    result_4_lya_from_APD = []

    for repeat_index,repeat in enumerate(result_4_repeat_list):
        result_4_lya_from_APD.append([])    
        for regions in range(1):
            result_4_lya_from_APD[repeat_index].append([])
            for tau_r_index in range(len(result_4_tau_r_list)):
                result_4_lya_from_APD[repeat_index][regions].append([]) 
                for tau_pw_index in range(len(result_4_tau_pw_list)):

                    APD = APDs[repeat_index,tau_r_index,tau_pw_index]
                    result = []
                    for point in range(0,64,5):
                        embedded_data = embed_data(APD[point],m_APD)

                        result.append(wolf_lya_exp(embedded_data,epsilon_APD,'middle',np.pi / 4,50))

                    result_4_lya_from_APD[repeat_index][regions][tau_r_index].append(sum(result)/len(result))       

    result_4_lya_from_APD_spatial = []

    for repeat_index,repeat in enumerate(result_4_repeat_list):
        result_4_lya_from_APD_spatial.append([])    
        for regions in range(1):
            result_4_lya_from_APD_spatial[repeat_index].append([]) 
            for tau_r_index in range(len(result_4_tau_r_list)):
                result_4_lya_from_APD_spatial[repeat_index][regions].append([])
                for tau_pw_index in range(len(result_4_tau_pw_list)):

                    all_points = APDs[repeat_index,tau_r_index,tau_pw_index]
                    APD = []
                    for point in range(0,64,5):
                        APD.append(all_points[point])

                    tau_pw = result_4_tau_pw_list[tau_pw_index]
                    tau_r = result_4_tau_r_list[tau_r_index]

                    result = get_spatial_lya_exp(APD,num_of_point,4,50,1)[1]

                    result_4_lya_from_APD_spatial[repeat_index][regions][tau_r_index].append(sum(result)/len(result))

    result_APD = avg_repeat(result_4_lya_from_APD)[0] 
    result_APD_spatial = avg_repeat(result_4_lya_from_APD_spatial)[0]
    exp_lib[dt_multiplier] = [result_APD,result_APD_spatial]   
    return 

def helper(result_uvw,exp_lib):
    def MSE(lst):
        if not lst:
            return -1
        result = 0
        N = len(lst)
        for i in range(N):
            result += (lst[i] - result_uvw[i])**2
        result /= N
        return result
        
    x1 = []
    result_t_1 = []
    result_s_1 = []
    for key in exp_lib:
        x1.append(key)
        temporal,spatial = exp_lib[key]
        t_MSE = MSE(temporal)
        s_MSE = MSE(spatial)
        result_t_1.append(t_MSE)
        result_s_1.append(s_MSE)   
    return x1,result_t_1,result_s_1

# %%
with open('result_tau_d_lya_from_uvw_non_transition.pkl', 'rb') as f:
    result_4_lya_from_uvw_non_transition = pickle.load(f)

with open('result_tau_d_lya_from_uvw_transition.pkl', 'rb') as f:
    result_4_lya_from_uvw_transition = pickle.load(f)
result_uvw_non_transition = avg_repeat2(result_4_lya_from_uvw_non_transition)[0]
result_uvw_transition = avg_repeat2(result_4_lya_from_uvw_transition)[0]
result_tau_d_uvw = result_uvw_non_transition[:4] + result_uvw_transition + result_uvw_non_transition[4:]

# taur
with open('result_tau_r_lya_from_uvw.pkl', 'rb') as f:
    result_tau_r_uvw = pickle.load(f)
# tausi
with open('result_tau_si_lya_from_uvw.pkl', 'rb') as f:
    result_tau_si_uvw = pickle.load(f)
# tau0
with open('result_tau_0_lya_from_uvw.pkl', 'rb') as f:
    result_tau_0_uvw = pickle.load(f)    


tau_r_list = [33.5,33.6,33.7,33.8,33.9,34,34.1,34.2,34.3,34.4,34.5]          
tau_si_list = [26.45,26.5,26.55,26.6 ,26.65 ,26.7 ,26.75,26.8,26.85,26.9,26.95]
tau_0_list = [7.2,7.4,7.6,7.8,8,8.2,8.4,8.6,8.8,9,9.2,9.4]
with open('result_tau_d_list_non_transition.pkl', 'rb') as f:
    tau_d_list_non_transition = pickle.load(f)

with open('result_tau_d_list_transition.pkl', 'rb') as f:
    tau_d_list_transition = pickle.load(f)   
tau_d_list = tau_d_list_non_transition[:4] + tau_d_list_transition + tau_d_list_non_transition[4:]

exp_lib_si = {}
exp_lib_r = {}
exp_lib_d = {}
exp_lib_0 = {}
APDs_dict = {}
dt_multiplier_lst = [1,2,3,4,5,6,7,8,9]
order = [['tau_r',tau_r_list],['tau_si',tau_si_list],['tau_0',tau_0_list],['tau_d',tau_d_list]]

for dt_multiplier in dt_multiplier_lst:
    for para_pair in order:
        para_name = para_pair[0]
        file_name = 'APDs_' + para_name + '_dt_multiplier_' + str(dt_multiplier) + '.pkl'
        # now load APDs
        with open(file_name, 'rb') as f:
            APDs_dict[para_name] = pickle.load(f)
            
    f_exp_3(APDs_dict['tau_si'],tau_si_list,result_tau_si_uvw,dt_multiplier,exp_lib_si)
    f_exp_3(APDs_dict['tau_r'],tau_r_list,result_tau_r_uvw,dt_multiplier,exp_lib_r)
    f_exp_3(APDs_dict['tau_d'],tau_d_list,result_tau_d_uvw,dt_multiplier,exp_lib_d)
    f_exp_3(APDs_dict['tau_0'],tau_0_list,result_tau_0_uvw,dt_multiplier,exp_lib_0)
# Out:
# 1
# 1
# cannot find neighbor for point  1641 ,dis =  135.99874371495972
# cannot find neighbor for point  1663 ,dis =  130.38458399891033
# cannot find neighbor for point  1662 ,dis =  132.7087704116431
# 1
# cannot find neighbor for point  1557 ,dis =  141.50626626235905
# cannot find neighbor for point  1582 ,dis =  121.21200531237174
# cannot find neighbor for point  1597 ,dis =  123.08539557262561
# cannot find neighbor for point  1582 ,dis =  120.66719711091393
# cannot find neighbor for point  1598 ,dis =  149.56366649988772
# cannot find neighbor for point  1557 ,dis =  125.33432372935256
# cannot find neighbor for point  1596 ,dis =  129.58512908040132
# cannot find neighbor for point  1145 ,dis =  123.7493743798204
# cannot find neighbor for point  113 ,dis =  120.05397352283704
# 1
# cannot find neighbor for point  1081 ,dis =  124.83984436121969
# cannot find neighbor for point  1443 ,dis =  120.1374001423938
# cannot find neighbor for point  1455 ,dis =  129.62786172515916
# 2
# 2
# cannot find neighbor for point  1319 ,dis =  127.88381164130325
# cannot find neighbor for point  1641 ,dis =  135.82056412120414
# cannot find neighbor for point  1663 ,dis =  129.4483171850738
# cannot find neighbor for point  1655 ,dis =  120.02838632198812
# 2
# cannot find neighbor for point  1557 ,dis =  141.21396158626285
# cannot find neighbor for point  1597 ,dis =  121.18667372659783
# cannot find neighbor for point  1582 ,dis =  120.06528781523785
# cannot find neighbor for point  1598 ,dis =  150.88418122166266
# cannot find neighbor for point  1557 ,dis =  125.59308044986697
# cannot find neighbor for point  1528 ,dis =  134.31341728669815
# cannot find neighbor for point  1596 ,dis =  130.06560279283747
# 2
# cannot find neighbor for point  1081 ,dis =  123.46163090473813
# cannot find neighbor for point  1446 ,dis =  145.75588521654473
# cannot find neighbor for point  1316 ,dis =  153.9914214430573
# 3
# cannot find neighbor for point  899 ,dis =  137.82776173219415
# 3
# cannot find neighbor for point  789 ,dis =  153.8838255385082
# 4
# cannot find neighbor for point  1370 ,dis =  144.6489012484973
# cannot find neighbor for point  1089 ,dis =  176.24091630810761
# cannot find neighbor for point  1064 ,dis =  132.51010005772278
# cannot find neighbor for point  1615 ,dis =  126.01353943310895
# cannot find neighbor for point  1383 ,dis =  126.78797358782889
# cannot find neighbor for point  1589 ,dis =  128.6635284815265
# cannot find neighbor for point  1509 ,dis =  137.8531238446498
# cannot find neighbor for point  1643 ,dis =  129.80765025965812
# cannot find neighbor for point  1435 ,dis =  189.31147163751282
# cannot find neighbor for point  1290 ,dis =  139.16022347704242
# cannot find neighbor for point  1277 ,dis =  143.0473118205989
# cannot find neighbor for point  1553 ,dis =  124.80382968964898
# cannot find neighbor for point  1586 ,dis =  156.22719119462482
# cannot find neighbor for point  1499 ,dis =  133.58308144155978
# cannot find neighbor for point  1329 ,dis =  127.60048957315
# cannot find neighbor for point  1445 ,dis =  138.28021116233523
# cannot find neighbor for point  1272 ,dis =  134.28981167270848
# cannot find neighbor for point  862 ,dis =  142.20890392480425
# cannot find neighbor for point  1069 ,dis =  139.85681398043786
# cannot find neighbor for point  1617 ,dis =  139.61830332817
# cannot find neighbor for point  1373 ,dis =  154.83238933495258
# cannot find neighbor for point  1245 ,dis =  126.57673532977361
# cannot find neighbor for point  1416 ,dis =  134.71077409197284
# cannot find neighbor for point  1507 ,dis =  153.76729086234772
# cannot find neighbor for point  830 ,dis =  123.22414989529317
# cannot find neighbor for point  1453 ,dis =  129.71399633029935
# cannot find neighbor for point  1096 ,dis =  142.33077641403275
# cannot find neighbor for point  1290 ,dis =  123.69572315906558
# cannot find neighbor for point  1571 ,dis =  141.22457509365492
# cannot find neighbor for point  1566 ,dis =  122.65504594523307
# 5
# cannot find neighbor for point  1256 ,dis =  126.62440973820597
# cannot find neighbor for point  902 ,dis =  132.22699953490056
# cannot find neighbor for point  764 ,dis =  157.69634055135805
# cannot find neighbor for point  1396 ,dis =  131.3441380204179
# cannot find neighbor for point  880 ,dis =  126.51052910523838
# cannot find neighbor for point  922 ,dis =  134.08249191291026
# cannot find neighbor for point  1075 ,dis =  129.82395168765277
# cannot find neighbor for point  1106 ,dis =  139.6837069144353
# cannot find neighbor for point  1048 ,dis =  131.21679411831624
# cannot find neighbor for point  1437 ,dis =  133.7158838447662
# cannot find neighbor for point  1194 ,dis =  120.94833919011113
# cannot find neighbor for point  898 ,dis =  128.3074929173643
# cannot find neighbor for point  901 ,dis =  125.6847672582581
# cannot find neighbor for point  1500 ,dis =  127.95724588785916
# cannot find neighbor for point  1330 ,dis =  132.59715793393565
# 5
# cannot find neighbor for point  1117 ,dis =  128.9887131110646
# cannot find neighbor for point  678 ,dis =  162.42754444878187
# cannot find neighbor for point  1101 ,dis =  129.1987280753091
# cannot find neighbor for point  1296 ,dis =  120.24413822429987
# cannot find neighbor for point  923 ,dis =  142.1663926795682
# cannot find neighbor for point  755 ,dis =  120.19474055797431
# cannot find neighbor for point  1328 ,dis =  133.55962439341613
# cannot find neighbor for point  1107 ,dis =  130.2513370463102
# cannot find neighbor for point  1374 ,dis =  137.23102399285025
# cannot find neighbor for point  693 ,dis =  138.12396118932324
# cannot find neighbor for point  1021 ,dis =  120.33672641327561
# cannot find neighbor for point  745 ,dis =  132.60502096582422
# cannot find neighbor for point  1153 ,dis =  130.8403581869048
# cannot find neighbor for point  649 ,dis =  199.14495410555784
# cannot find neighbor for point  642 ,dis =  130.04747882472415
# cannot find neighbor for point  643 ,dis =  130.2207549799682
# cannot find neighbor for point  861 ,dis =  126.68421233366851
# cannot find neighbor for point  615 ,dis =  150.53549873985165
# cannot find neighbor for point  622 ,dis =  126.06342467742067
# cannot find neighbor for point  1150 ,dis =  121.52271035593314
# cannot find neighbor for point  977 ,dis =  125.2795508856514
# cannot find neighbor for point  686 ,dis =  139.66697096881913
# cannot find neighbor for point  822 ,dis =  120.14873493402789
# cannot find neighbor for point  1478 ,dis =  128.68309133814827
# cannot find neighbor for point  1444 ,dis =  122.45012812026857
# cannot find neighbor for point  1368 ,dis =  141.03913060613536
# cannot find neighbor for point  699 ,dis =  134.23770809971833
# cannot find neighbor for point  1161 ,dis =  142.02630807487384
# cannot find neighbor for point  926 ,dis =  120.8678311964335
# cannot find neighbor for point  1104 ,dis =  120.33190584674264
# cannot find neighbor for point  686 ,dis =  140.25576230240347
# cannot find neighbor for point  967 ,dis =  120.49440898938252
# cannot find neighbor for point  1282 ,dis =  120.07776216508677
# cannot find neighbor for point  1178 ,dis =  192.29629560336494
# cannot find neighbor for point  1256 ,dis =  166.0402541672399
# cannot find neighbor for point  1058 ,dis =  129.78616863262582
# cannot find neighbor for point  1093 ,dis =  153.22444204165134
# cannot find neighbor for point  974 ,dis =  138.4869549689562
# cannot find neighbor for point  1560 ,dis =  129.38768037136046
# cannot find neighbor for point  1316 ,dis =  129.85236564993974
# cannot find neighbor for point  726 ,dis =  131.4413817440143
# cannot find neighbor for point  717 ,dis =  157.35824973590945
# cannot find neighbor for point  871 ,dis =  123.97134944601534
# cannot find neighbor for point  1022 ,dis =  160.51537348636694
# cannot find neighbor for point  1249 ,dis =  149.95515865711073
# cannot find neighbor for point  1197 ,dis =  126.18634047463442
# cannot find neighbor for point  652 ,dis =  120.72059000759917
# cannot find neighbor for point  1046 ,dis =  128.72682864260668
# cannot find neighbor for point  1404 ,dis =  120.05440970832875
# cannot find neighbor for point  651 ,dis =  136.71059513887735
# cannot find neighbor for point  1243 ,dis =  132.70408779217743
# cannot find neighbor for point  1146 ,dis =  120.09775945549264
# cannot find neighbor for point  1641 ,dis =  148.70644903733037
# cannot find neighbor for point  1663 ,dis =  211.05735160036429
# cannot find neighbor for point  1647 ,dis =  180.2993603650981
# cannot find neighbor for point  1645 ,dis =  127.2105865492461
# cannot find neighbor for point  1646 ,dis =  121.04131845973117
# cannot find neighbor for point  1643 ,dis =  153.63308379441673
# cannot find neighbor for point  1643 ,dis =  126.92054464580586
# cannot find neighbor for point  1651 ,dis =  144.774360420405
# cannot find neighbor for point  89 ,dis =  129.27895577962965
# cannot find neighbor for point  1536 ,dis =  153.25369665682743
# cannot find neighbor for point  1551 ,dis =  145.45942930391595
# cannot find neighbor for point  970 ,dis =  131.05661693827386
# cannot find neighbor for point  922 ,dis =  137.7749351887271
# cannot find neighbor for point  909 ,dis =  130.41845871555017
# cannot find neighbor for point  1315 ,dis =  150.1400587932101
# 6
# cannot find neighbor for point  868 ,dis =  149.68071879588462
# cannot find neighbor for point  1506 ,dis =  142.85136233755264
# cannot find neighbor for point  1515 ,dis =  128.66370057495982
# cannot find neighbor for point  1495 ,dis =  151.5922042511032
# cannot find neighbor for point  1513 ,dis =  191.80925720755897
# cannot find neighbor for point  1463 ,dis =  134.46618639604347
# cannot find neighbor for point  1285 ,dis =  134.44261013614695
# cannot find neighbor for point  1006 ,dis =  129.23717675454094
# cannot find neighbor for point  1275 ,dis =  142.10530089943177
# cannot find neighbor for point  1271 ,dis =  135.8884701784401
# cannot find neighbor for point  1157 ,dis =  133.60648284748837
# cannot find neighbor for point  745 ,dis =  132.60502096582422
# cannot find neighbor for point  1153 ,dis =  130.8403581869048
# cannot find neighbor for point  713 ,dis =  125.09151942153713
# cannot find neighbor for point  941 ,dis =  127.31587704247744
# cannot find neighbor for point  957 ,dis =  149.8388770244927
# cannot find neighbor for point  1131 ,dis =  149.36160538599444
# cannot find neighbor for point  1130 ,dis =  144.30245485112778
# cannot find neighbor for point  1068 ,dis =  134.0593950037639
# cannot find neighbor for point  1247 ,dis =  132.25888318390744
# cannot find neighbor for point  842 ,dis =  142.71381748278168
# cannot find neighbor for point  1230 ,dis =  133.52687116600484
# cannot find neighbor for point  826 ,dis =  120.07455135806111
# cannot find neighbor for point  1450 ,dis =  192.52538460935523
# cannot find neighbor for point  1092 ,dis =  121.39863605670537
# cannot find neighbor for point  963 ,dis =  120.73966940185015
# cannot find neighbor for point  948 ,dis =  134.37691299511684
# cannot find neighbor for point  1315 ,dis =  149.0898288909386
# cannot find neighbor for point  1428 ,dis =  137.96661900324247
# cannot find neighbor for point  827 ,dis =  139.2668807259705
# cannot find neighbor for point  839 ,dis =  145.6762136652768
# cannot find neighbor for point  699 ,dis =  134.23770809971833
# cannot find neighbor for point  1161 ,dis =  142.02630807487384
# cannot find neighbor for point  926 ,dis =  120.8678311964335
# cannot find neighbor for point  960 ,dis =  122.79432783078285
# cannot find neighbor for point  709 ,dis =  170.82431590069683
# cannot find neighbor for point  1251 ,dis =  130.33858763262484
# cannot find neighbor for point  818 ,dis =  139.36830200003726
# cannot find neighbor for point  1315 ,dis =  185.26205171199354
# cannot find neighbor for point  804 ,dis =  126.01948697546203
# cannot find neighbor for point  568 ,dis =  129.02461332701463
# cannot find neighbor for point  1414 ,dis =  130.05136765474225
# cannot find neighbor for point  927 ,dis =  135.0641449440109
# cannot find neighbor for point  1661 ,dis =  206.6085380784372
# cannot find neighbor for point  1263 ,dis =  128.03293624700086
# cannot find neighbor for point  1541 ,dis =  124.08460365172986
# cannot find neighbor for point  1658 ,dis =  120.15493116765846
# cannot find neighbor for point  692 ,dis =  126.23170678769458
# cannot find neighbor for point  1298 ,dis =  145.00092063058094
# cannot find neighbor for point  985 ,dis =  133.8208213031437
# cannot find neighbor for point  1262 ,dis =  148.3811101897746
# cannot find neighbor for point  1264 ,dis =  191.6735185772015
# cannot find neighbor for point  1201 ,dis =  145.79491467146042
# cannot find neighbor for point  1417 ,dis =  135.85751204792257
# cannot find neighbor for point  859 ,dis =  127.9470315688996
# cannot find neighbor for point  1151 ,dis =  142.50120653495856
# cannot find neighbor for point  1673 ,dis =  204.19969235002114
# cannot find neighbor for point  1490 ,dis =  147.2207189916749
# cannot find neighbor for point  1594 ,dis =  145.90996901041316
# cannot find neighbor for point  1175 ,dis =  144.2030465275101
# cannot find neighbor for point  1704 ,dis =  148.22955163203207
# cannot find neighbor for point  1285 ,dis =  147.66882084776378
# cannot find neighbor for point  901 ,dis =  132.49587752456821
# cannot find neighbor for point  983 ,dis =  137.14598241133677
# cannot find neighbor for point  1334 ,dis =  138.4811934502142
# cannot find neighbor for point  1129 ,dis =  140.96197858279243
# cannot find neighbor for point  759 ,dis =  130.1409675955298
# cannot find neighbor for point  908 ,dis =  161.24390343864277
# cannot find neighbor for point  1209 ,dis =  177.52980278526582
# cannot find neighbor for point  683 ,dis =  136.27775653972523
# cannot find neighbor for point  838 ,dis =  213.1630594049392
# cannot find neighbor for point  821 ,dis =  124.97913261734428
# cannot find neighbor for point  1281 ,dis =  138.01254901598966
# cannot find neighbor for point  1025 ,dis =  129.93037859455936
# cannot find neighbor for point  685 ,dis =  231.08671102828455
# cannot find neighbor for point  851 ,dis =  146.4134805306559
# cannot find neighbor for point  997 ,dis =  189.34726333788814
# cannot find neighbor for point  677 ,dis =  120.24780485418641
# cannot find neighbor for point  808 ,dis =  124.22024156364425
# cannot find neighbor for point  716 ,dis =  168.7792126813221
# cannot find neighbor for point  1248 ,dis =  125.0726612835128
# cannot find neighbor for point  1269 ,dis =  175.82338870759486
# cannot find neighbor for point  951 ,dis =  170.10388813843898
# cannot find neighbor for point  1279 ,dis =  141.1318467896583
# cannot find neighbor for point  1059 ,dis =  151.5564395566038
# cannot find neighbor for point  1164 ,dis =  149.78415596400004
# cannot find neighbor for point  791 ,dis =  148.74438435482088
# cannot find neighbor for point  1025 ,dis =  123.12863785878828
# cannot find neighbor for point  1306 ,dis =  167.33120659456821
# cannot find neighbor for point  930 ,dis =  122.1811026381013
# cannot find neighbor for point  849 ,dis =  126.0566176556521
# cannot find neighbor for point  700 ,dis =  220.56780981165295
# cannot find neighbor for point  1171 ,dis =  129.2930108609848
# cannot find neighbor for point  879 ,dis =  135.2312455944155
# cannot find neighbor for point  1392 ,dis =  123.0547238807522
# cannot find neighbor for point  1340 ,dis =  127.72397950563747
# cannot find neighbor for point  1492 ,dis =  122.38283671130765
# cannot find neighbor for point  1447 ,dis =  158.52440399595136
# cannot find neighbor for point  1662 ,dis =  126.14365689970329
# cannot find neighbor for point  1298 ,dis =  142.89620626865937
# cannot find neighbor for point  864 ,dis =  135.49088720091063
# cannot find neighbor for point  1218 ,dis =  146.60644997162265
# cannot find neighbor for point  1371 ,dis =  142.68594077050386
# cannot find neighbor for point  912 ,dis =  145.6252288100125
# cannot find neighbor for point  871 ,dis =  123.96522663146125
# cannot find neighbor for point  1085 ,dis =  146.0277515006706
# cannot find neighbor for point  1190 ,dis =  137.426392389544
# cannot find neighbor for point  1082 ,dis =  174.90894714178916
# cannot find neighbor for point  1003 ,dis =  136.63304232023523
# cannot find neighbor for point  1243 ,dis =  136.4993314076307
# cannot find neighbor for point  1019 ,dis =  128.66354094284145
# cannot find neighbor for point  1287 ,dis =  172.1145564215115
# cannot find neighbor for point  806 ,dis =  152.80775809892933
# cannot find neighbor for point  712 ,dis =  135.4451133854757
# cannot find neighbor for point  815 ,dis =  168.65224627767046
# cannot find neighbor for point  960 ,dis =  179.48197293674843
# cannot find neighbor for point  1180 ,dis =  121.90263887347245
# cannot find neighbor for point  1577 ,dis =  140.95387051236364
# cannot find neighbor for point  877 ,dis =  148.52818042093278
# cannot find neighbor for point  1579 ,dis =  146.05885194709867
# cannot find neighbor for point  1648 ,dis =  142.22507798040039
# cannot find neighbor for point  1646 ,dis =  141.69481953068964
# cannot find neighbor for point  1620 ,dis =  141.23611136131166
# cannot find neighbor for point  1305 ,dis =  145.33063357819424
# cannot find neighbor for point  1141 ,dis =  144.9622963507664
# cannot find neighbor for point  1102 ,dis =  146.62055255200957
# cannot find neighbor for point  1219 ,dis =  124.38545923698604
# cannot find neighbor for point  1170 ,dis =  170.33144790428443
# cannot find neighbor for point  682 ,dis =  145.58874746382108
# cannot find neighbor for point  654 ,dis =  155.9185022955406
# cannot find neighbor for point  689 ,dis =  293.11520544124727
# cannot find neighbor for point  899 ,dis =  171.0701577250646
# cannot find neighbor for point  1033 ,dis =  145.4611466744403
# cannot find neighbor for point  1127 ,dis =  158.8996698439382
# cannot find neighbor for point  979 ,dis =  126.75416178174
# cannot find neighbor for point  930 ,dis =  146.80416244911768
# cannot find neighbor for point  756 ,dis =  127.83887279930596
# cannot find neighbor for point  921 ,dis =  128.20352167692153
# cannot find neighbor for point  689 ,dis =  144.7638288538094
# cannot find neighbor for point  892 ,dis =  164.4441972849546
# cannot find neighbor for point  924 ,dis =  135.99676139335386
# cannot find neighbor for point  995 ,dis =  142.29433987929164
# cannot find neighbor for point  586 ,dis =  133.67827136400538
# cannot find neighbor for point  1348 ,dis =  135.75966866632288
# cannot find neighbor for point  1391 ,dis =  135.6045498987499
# cannot find neighbor for point  1001 ,dis =  171.42243036590017
# cannot find neighbor for point  730 ,dis =  261.0564248731002
# cannot find neighbor for point  986 ,dis =  141.64633973684386
# cannot find neighbor for point  1381 ,dis =  133.07473111588303
# cannot find neighbor for point  1478 ,dis =  142.0192648683917
# cannot find neighbor for point  1391 ,dis =  125.39780741072062
# cannot find neighbor for point  1231 ,dis =  139.10191490073566
# cannot find neighbor for point  1255 ,dis =  139.17816508635784
# cannot find neighbor for point  1102 ,dis =  138.98011568400074
# cannot find neighbor for point  757 ,dis =  126.26257358494209
# cannot find neighbor for point  825 ,dis =  122.47078288289053
# cannot find neighbor for point  1121 ,dis =  122.66840022899883
# cannot find neighbor for point  1120 ,dis =  127.44323496478347
# cannot find neighbor for point  1180 ,dis =  123.33164690641561
# cannot find neighbor for point  715 ,dis =  120.7519350504973
# cannot find neighbor for point  760 ,dis =  125.36967085855349
# cannot find neighbor for point  672 ,dis =  127.92736613941452
# cannot find neighbor for point  689 ,dis =  139.31359778677842
# cannot find neighbor for point  788 ,dis =  144.29790105113847
# cannot find neighbor for point  701 ,dis =  123.29811578340905
# cannot find neighbor for point  759 ,dis =  144.46239118118538
# cannot find neighbor for point  965 ,dis =  143.9590706069981
# cannot find neighbor for point  1090 ,dis =  123.26775517572132
# cannot find neighbor for point  708 ,dis =  169.2236029878258
# cannot find neighbor for point  1226 ,dis =  121.63915835411797
# cannot find neighbor for point  1098 ,dis =  147.40024615982222
# cannot find neighbor for point  625 ,dis =  126.33996519040703
# cannot find neighbor for point  571 ,dis =  213.0103095009106
# cannot find neighbor for point  819 ,dis =  180.51783014764624
# cannot find neighbor for point  845 ,dis =  120.11355334936987
# cannot find neighbor for point  1238 ,dis =  135.21057543405456
# cannot find neighbor for point  1065 ,dis =  128.5296230918362
# cannot find neighbor for point  1154 ,dis =  121.302614957664
# cannot find neighbor for point  835 ,dis =  138.80147025652641
# cannot find neighbor for point  852 ,dis =  184.81022979907533
# cannot find neighbor for point  1127 ,dis =  136.86448752776167
# cannot find neighbor for point  1281 ,dis =  126.96290283716654
# cannot find neighbor for point  646 ,dis =  142.05332014985657
# cannot find neighbor for point  908 ,dis =  161.24390343864277
# cannot find neighbor for point  1209 ,dis =  177.52980278526582
# cannot find neighbor for point  683 ,dis =  136.27775653972523
# cannot find neighbor for point  838 ,dis =  213.1630594049392
# ...
# cannot find neighbor for point  1089 ,dis =  131.26509377410014
# cannot find neighbor for point  645 ,dis =  155.07092283008927
# cannot find neighbor for point  668 ,dis =  138.05442231556168
# cannot find neighbor for point  665 ,dis =  138.26241706553154
# cannot find neighbor for point  601 ,dis =  125.27535742290671
# cannot find neighbor for point  1085 ,dis =  192.52570767934873
# cannot find neighbor for point  917 ,dis =  134.87419337040552
# cannot find neighbor for point  1213 ,dis =  179.68859380048585
# cannot find neighbor for point  948 ,dis =  173.47794126221524
# cannot find neighbor for point  1280 ,dis =  180.42772488275472
# cannot find neighbor for point  1242 ,dis =  151.78221975767636
# cannot find neighbor for point  711 ,dis =  182.53932898735843
# cannot find neighbor for point  1300 ,dis =  180.44002906843593
# cannot find neighbor for point  1273 ,dis =  179.25074262522008
# cannot find neighbor for point  1462 ,dis =  148.16929505236126
# cannot find neighbor for point  1355 ,dis =  181.2166300486249
# cannot find neighbor for point  1078 ,dis =  167.8087054822087
# cannot find neighbor for point  711 ,dis =  145.96265322444174
# cannot find neighbor for point  684 ,dis =  149.97356485074212
# cannot find neighbor for point  1035 ,dis =  190.4146710215932
# cannot find neighbor for point  724 ,dis =  133.39916831263437
# cannot find neighbor for point  760 ,dis =  157.16903222675978
# cannot find neighbor for point  591 ,dis =  168.7453352079743
# cannot find neighbor for point  600 ,dis =  143.84602059514452
# cannot find neighbor for point  944 ,dis =  153.26458043315134
# cannot find neighbor for point  879 ,dis =  142.00277825766935
# cannot find neighbor for point  596 ,dis =  182.8066020022872
# cannot find neighbor for point  519 ,dis =  123.2238991167596
# cannot find neighbor for point  907 ,dis =  131.05970094834538
# cannot find neighbor for point  551 ,dis =  138.41053953276028
# cannot find neighbor for point  792 ,dis =  141.80716287632524
# cannot find neighbor for point  835 ,dis =  147.57995006218366
# cannot find neighbor for point  774 ,dis =  139.72894586208946
# cannot find neighbor for point  1051 ,dis =  120.7043588952553
# cannot find neighbor for point  607 ,dis =  169.43767774771592
# cannot find neighbor for point  886 ,dis =  241.13145702341214
# cannot find neighbor for point  903 ,dis =  130.70771056295445
# cannot find neighbor for point  611 ,dis =  140.85099716300266
# cannot find neighbor for point  709 ,dis =  162.0051988854056
# cannot find neighbor for point  883 ,dis =  131.2211551548845
# cannot find neighbor for point  557 ,dis =  173.43595061929406
# cannot find neighbor for point  905 ,dis =  182.8573361082509
# cannot find neighbor for point  1135 ,dis =  120.94406002098111
# cannot find neighbor for point  664 ,dis =  144.65326038881278
# cannot find neighbor for point  545 ,dis =  180.59106628576856
# cannot find neighbor for point  953 ,dis =  174.4709645183948
# cannot find neighbor for point  593 ,dis =  138.29791305042022
# cannot find neighbor for point  554 ,dis =  134.1294999185173
# cannot find neighbor for point  721 ,dis =  143.17226178243442
# cannot find neighbor for point  749 ,dis =  125.35524950056453
# cannot find neighbor for point  474 ,dis =  141.38149326623846
# cannot find neighbor for point  475 ,dis =  136.5733187591295
# cannot find neighbor for point  990 ,dis =  167.3894873687008
# cannot find neighbor for point  661 ,dis =  130.19153899850275
# cannot find neighbor for point  668 ,dis =  180.46670180815798
# cannot find neighbor for point  808 ,dis =  145.90661435019555
# cannot find neighbor for point  905 ,dis =  163.5311088018871
# cannot find neighbor for point  818 ,dis =  123.06206857292935
# cannot find neighbor for point  741 ,dis =  141.0690401226808
# cannot find neighbor for point  742 ,dis =  628.7434690547351
# cannot find neighbor for point  1154 ,dis =  157.0859103853117
# cannot find neighbor for point  622 ,dis =  124.56012879919517
# cannot find neighbor for point  587 ,dis =  181.6210382498966
# cannot find neighbor for point  505 ,dis =  151.94116784380714
# cannot find neighbor for point  788 ,dis =  144.85883054092716
# cannot find neighbor for point  854 ,dis =  127.08854894488034
# cannot find neighbor for point  916 ,dis =  121.87582420160028
# cannot find neighbor for point  686 ,dis =  222.09210927383378
# cannot find neighbor for point  860 ,dis =  149.0355438222929
# cannot find neighbor for point  590 ,dis =  178.15862579448324
# cannot find neighbor for point  600 ,dis =  151.17640195075677
# cannot find neighbor for point  918 ,dis =  154.65542922497403
# cannot find neighbor for point  706 ,dis =  187.26149732535887
# cannot find neighbor for point  830 ,dis =  165.90143538499566
# cannot find neighbor for point  1131 ,dis =  127.52012294069719
# cannot find neighbor for point  962 ,dis =  279.27198928121186
# cannot find neighbor for point  1281 ,dis =  123.47161734425869
# cannot find neighbor for point  1017 ,dis =  155.8525043739762
# cannot find neighbor for point  900 ,dis =  159.00959625708657
# cannot find neighbor for point  1120 ,dis =  170.21306445899504
# cannot find neighbor for point  918 ,dis =  194.35754505453193
# cannot find neighbor for point  1178 ,dis =  184.17664324532288
# cannot find neighbor for point  892 ,dis =  120.42317537292104
# cannot find neighbor for point  734 ,dis =  180.38991876742094
# cannot find neighbor for point  910 ,dis =  180.53623109412447
# cannot find neighbor for point  879 ,dis =  178.72088504956764
# cannot find neighbor for point  929 ,dis =  148.87242375373327
# cannot find neighbor for point  1097 ,dis =  141.57493842738992
# cannot find neighbor for point  778 ,dis =  180.92494519719315
# cannot find neighbor for point  976 ,dis =  180.21087068860538
# cannot find neighbor for point  909 ,dis =  154.3401818873193
# cannot find neighbor for point  826 ,dis =  148.9188965164494
# cannot find neighbor for point  603 ,dis =  152.6288695478154
# cannot find neighbor for point  632 ,dis =  128.93135849646396
# cannot find neighbor for point  555 ,dis =  121.64108782184027
# cannot find neighbor for point  554 ,dis =  126.65023731292328
# cannot find neighbor for point  538 ,dis =  220.7889669679832
# cannot find neighbor for point  766 ,dis =  138.46355561871624
# cannot find neighbor for point  543 ,dis =  192.04724469457457
# cannot find neighbor for point  595 ,dis =  138.3087117510331
# cannot find neighbor for point  900 ,dis =  129.6755136711724
# cannot find neighbor for point  785 ,dis =  154.14438217798562
# cannot find neighbor for point  501 ,dis =  128.16333621140615
# cannot find neighbor for point  515 ,dis =  158.18601802829446
# cannot find neighbor for point  502 ,dis =  143.119676246707
# cannot find neighbor for point  758 ,dis =  175.20030118267306
# cannot find neighbor for point  668 ,dis =  164.82626500588202
# cannot find neighbor for point  783 ,dis =  369.744529390752
# cannot find neighbor for point  1077 ,dis =  184.87896838355553
# cannot find neighbor for point  975 ,dis =  340.28923185362794
# cannot find neighbor for point  639 ,dis =  187.745012687492
# cannot find neighbor for point  720 ,dis =  157.40694220356835
# cannot find neighbor for point  509 ,dis =  145.83724896224336
# cannot find neighbor for point  1021 ,dis =  138.84341885615322
# cannot find neighbor for point  735 ,dis =  194.75231041479486
# cannot find neighbor for point  713 ,dis =  161.84219631616966
# cannot find neighbor for point  628 ,dis =  125.04831669471112
# cannot find neighbor for point  738 ,dis =  141.34796719073
# cannot find neighbor for point  538 ,dis =  211.8519495154904
# cannot find neighbor for point  524 ,dis =  195.4960140082863
# cannot find neighbor for point  693 ,dis =  171.69400169472416
# cannot find neighbor for point  1097 ,dis =  147.59899677757963
# cannot find neighbor for point  1061 ,dis =  187.73596750400495
# cannot find neighbor for point  738 ,dis =  141.33484187585077
# cannot find neighbor for point  528 ,dis =  148.0175047870308
# cannot find neighbor for point  850 ,dis =  276.9771082469025
# cannot find neighbor for point  500 ,dis =  180.9081528144696
# cannot find neighbor for point  537 ,dis =  183.56737459531325
# cannot find neighbor for point  564 ,dis =  132.67291501325818
# cannot find neighbor for point  754 ,dis =  173.53646289185977
# cannot find neighbor for point  565 ,dis =  175.20901383340797
# cannot find neighbor for point  569 ,dis =  124.44651967975848
# cannot find neighbor for point  583 ,dis =  198.55322184016975
# cannot find neighbor for point  621 ,dis =  121.37381321078554
# cannot find neighbor for point  670 ,dis =  153.49873812919014
# cannot find neighbor for point  1262 ,dis =  167.6964105829558
# cannot find neighbor for point  634 ,dis =  149.0617269367568
# cannot find neighbor for point  713 ,dis =  221.8611487525545
# cannot find neighbor for point  1035 ,dis =  129.04329385348606
# cannot find neighbor for point  733 ,dis =  127.09596760226324
# cannot find neighbor for point  1074 ,dis =  186.1745258894238
# cannot find neighbor for point  725 ,dis =  158.9572504597178
# cannot find neighbor for point  591 ,dis =  122.43375511156341
# cannot find neighbor for point  688 ,dis =  138.47244360084008
# cannot find neighbor for point  751 ,dis =  150.2901445616895
# cannot find neighbor for point  864 ,dis =  143.60228646688367
# cannot find neighbor for point  760 ,dis =  240.22411609950944
# cannot find neighbor for point  670 ,dis =  161.08245304357843
# cannot find neighbor for point  839 ,dis =  150.54109373381644
# cannot find neighbor for point  678 ,dis =  137.64688570277247
# cannot find neighbor for point  836 ,dis =  357.60469947978083
# cannot find neighbor for point  848 ,dis =  125.67676898284014
# cannot find neighbor for point  753 ,dis =  141.1781241151013
# cannot find neighbor for point  679 ,dis =  130.2154125440973
# cannot find neighbor for point  533 ,dis =  155.22878645296348
# cannot find neighbor for point  656 ,dis =  225.35416805280562
# cannot find neighbor for point  778 ,dis =  200.7797717926726
# cannot find neighbor for point  822 ,dis =  162.4753755004421
# cannot find neighbor for point  794 ,dis =  122.25547457199353
# cannot find neighbor for point  563 ,dis =  143.3906898768258
# cannot find neighbor for point  884 ,dis =  180.44956656950686
# cannot find neighbor for point  1357 ,dis =  154.21758319347498
# cannot find neighbor for point  1406 ,dis =  176.73758393834132
# cannot find neighbor for point  1199 ,dis =  149.28722863483753
# cannot find neighbor for point  1331 ,dis =  180.13406746407549
# cannot find neighbor for point  1357 ,dis =  180.0064316850599
# cannot find neighbor for point  1014 ,dis =  180.2872844494213
# cannot find neighbor for point  1487 ,dis =  177.25613897304473
# cannot find neighbor for point  774 ,dis =  177.09797939814345
# cannot find neighbor for point  1262 ,dis =  149.59669723088186
# cannot find neighbor for point  -28 ,dis =  100000000.0
# cannot find neighbor for point  -27 ,dis =  100000000.0
# cannot find neighbor for point  -26 ,dis =  100000000.0
# cannot find neighbor for point  -25 ,dis =  100000000.0
# cannot find neighbor for point  -24 ,dis =  100000000.0
# cannot find neighbor for point  -23 ,dis =  100000000.0
# cannot find neighbor for point  -22 ,dis =  100000000.0
# cannot find neighbor for point  -21 ,dis =  100000000.0
# cannot find neighbor for point  -20 ,dis =  100000000.0
# cannot find neighbor for point  -19 ,dis =  100000000.0
# cannot find neighbor for point  -18 ,dis =  100000000.0
# cannot find neighbor for point  -17 ,dis =  100000000.0
# cannot find neighbor for point  -16 ,dis =  100000000.0
# cannot find neighbor for point  -15 ,dis =  100000000.0
# cannot find neighbor for point  -14 ,dis =  100000000.0
# cannot find neighbor for point  -13 ,dis =  100000000.0
# cannot find neighbor for point  -12 ,dis =  100000000.0
# cannot find neighbor for point  -11 ,dis =  100000000.0
# cannot find neighbor for point  -10 ,dis =  100000000.0
# cannot find neighbor for point  -9 ,dis =  100000000.0
# cannot find neighbor for point  -8 ,dis =  100000000.0
# cannot find neighbor for point  -7 ,dis =  100000000.0
# cannot find neighbor for point  -6 ,dis =  100000000.0
# cannot find neighbor for point  -5 ,dis =  100000000.0
# cannot find neighbor for point  -4 ,dis =  100000000.0
# cannot find neighbor for point  -3 ,dis =  100000000.0
# cannot find neighbor for point  -2 ,dis =  100000000.0
# cannot find neighbor for point  -1 ,dis =  100000000.0
# cannot find neighbor for point  0 ,dis =  100000000.0
# cannot find neighbor for point  1 ,dis =  100000000.0
# cannot find neighbor for point  2 ,dis =  100000000.0
# cannot find neighbor for point  3 ,dis =  100000000.0
# cannot find neighbor for point  4 ,dis =  100000000.0
# cannot find neighbor for point  5 ,dis =  100000000.0
# cannot find neighbor for point  6 ,dis =  100000000.0
# cannot find neighbor for point  7 ,dis =  100000000.0
# cannot find neighbor for point  8 ,dis =  100000000.0
# cannot find neighbor for point  9 ,dis =  100000000.0
# cannot find neighbor for point  10 ,dis =  100000000.0
# cannot find neighbor for point  11 ,dis =  100000000.0
# cannot find neighbor for point  12 ,dis =  100000000.0
# cannot find neighbor for point  13 ,dis =  100000000.0
# cannot find neighbor for point  14 ,dis =  100000000.0
# cannot find neighbor for point  15 ,dis =  100000000.0
# cannot find neighbor for point  16 ,dis =  100000000.0
# cannot find neighbor for point  17 ,dis =  100000000.0
# cannot find neighbor for point  18 ,dis =  100000000.0
# cannot find neighbor for point  19 ,dis =  100000000.0
# cannot find neighbor for point  20 ,dis =  100000000.0
# cannot find neighbor for point  21 ,dis =  100000000.0
# cannot find neighbor for point  22 ,dis =  100000000.0
# cannot find neighbor for point  23 ,dis =  100000000.0
# cannot find neighbor for point  24 ,dis =  100000000.0
# cannot find neighbor for point  25 ,dis =  100000000.0
# cannot find neighbor for point  26 ,dis =  100000000.0
# cannot find neighbor for point  27 ,dis =  100000000.0
# cannot find neighbor for point  28 ,dis =  100000000.0
# cannot find neighbor for point  29 ,dis =  100000000.0
# cannot find neighbor for point  30 ,dis =  100000000.0
# cannot find neighbor for point  31 ,dis =  100000000.0
# cannot find neighbor for point  32 ,dis =  100000000.0
# cannot find neighbor for point  33 ,dis =  100000000.0
# cannot find neighbor for point  34 ,dis =  100000000.0
# cannot find neighbor for point  35 ,dis =  100000000.0
# cannot find neighbor for point  36 ,dis =  100000000.0
# cannot find neighbor for point  37 ,dis =  100000000.0
# cannot find neighbor for point  38 ,dis =  100000000.0
# cannot find neighbor for point  39 ,dis =  100000000.0
# cannot find neighbor for point  40 ,dis =  100000000.0
# cannot find neighbor for point  41 ,dis =  100000000.0
# cannot find neighbor for point  42 ,dis =  100000000.0
# cannot find neighbor for point  43 ,dis =  100000000.0
# cannot find neighbor for point  44 ,dis =  100000000.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 47
#      44     with open(file_name, 'rb') as f:
#      45         APDs_dict[para_name] = pickle.load(f)
# ---> 47 f_exp_3(APDs_dict['tau_si'],tau_si_list,result_tau_si_uvw,dt_multiplier,exp_lib_si)
#      48 f_exp_3(APDs_dict['tau_r'],tau_r_list,result_tau_r_uvw,dt_multiplier,exp_lib_r)
#      49 f_exp_3(APDs_dict['tau_d'],tau_d_list,result_tau_d_uvw,dt_multiplier,exp_lib_d)
#
# Cell In[3], line 28, in f_exp_3(APDs, result_4_tau_r_list, result_uvw, dt_multiplier, exp_lib)
#      25                 for point in range(0,64,5):
#      26                     embedded_data = embed_data(APD[point],m_APD)
# ---> 28                     result.append(wolf_lya_exp(embedded_data,epsilon_APD,'middle',np.pi / 4,50))
#      30                 result_4_lya_from_APD[repeat_index][regions][tau_r_index].append(sum(result)/len(result))
#      32 result_4_lya_from_APD_spatial = []
#
# Cell In[1], line 455, in wolf_lya_exp(embedded_data, epsilon, start_point, theta, boundary)
#     450     if result == False:
#     451         break
# --> 455 return log_sum /  (cur_point - start_point)
#
# ZeroDivisionError: division by zero

# %%
x1,result_t_3_si,result_s_3_si = helper(result_tau_si_uvw,exp_lib_si)
x1,result_t_3_r,result_s_3_r = helper(result_tau_r_uvw,exp_lib_r)
x1,result_t_3_d,result_s_3_d = helper(result_tau_d_uvw,exp_lib_d)
x1,result_t_3_0,result_s_3_0 = helper(result_tau_0_uvw,exp_lib_0)

result_t_3=np.zeros(len(x1))
result_s_3=np.zeros(len(x1))

for i in range(len(x1)):
    result_t_3[i] = (result_t_3_si[i] + result_t_3_r[i] + result_t_3_d[i] + result_t_3_0[i])/4
    result_t_3[i] = np.sqrt(result_t_3[i])
    
    result_s_3[i] = (result_s_3_si[i] + result_s_3_r[i] + result_s_3_d[i] + result_s_3_0[i])/4
    result_s_3[i] = np.sqrt(result_s_3[i])

# save result_t_s_1_2
# check if it alreay exists, if yes, skip
if os.path.isfile('result_t_3.pkl') != True:
    with open('result_t_3.pkl', 'wb') as f:
        pickle.dump(result_t_3, f)
        
if os.path.isfile('result_s_3.pkl') != True:        
    with open('result_s_3.pkl', 'wb') as f:
        pickle.dump(result_s_3, f)

# %%
with open('result_t_3.pkl','rb') as f:
    result_t_3 = pickle.load(f)
with open('result_s_3.pkl','rb') as f:
    result_s_3 = pickle.load(f)

# %%
import matplotlib.pyplot as plt
print(plt.rcParams['font.sans-serif'][0])
# Out:
# DejaVu Sans

# %%
plt.plot(x1,result_t_3,'-o',color = 'tab:orange')
plt.plot(x1,result_s_3,'-o',color = 'tab:green')

plt.legend([r'$\lambda^T$(APD)',r'$\lambda^S$(APD)',r'$\lambda^T$(APD)(Random Points)',r'$\lambda^S$(APD)(Random Points)'], fontsize=13)
plt.xlabel('Downsampling Factor (M)' ,fontsize=20)
plt.ylabel('RMSE', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=16)  # make tick labels larger
plt.gca().xaxis.set_major_locator(MaxNLocator(nbins=5))  # Max 5 ticks on x-axis
plt.gca().yaxis.set_major_locator(MaxNLocator(nbins=4))  # Max 5 ticks on y-axis
plt.savefig("exp3_all_four_para.png", bbox_inches='tight', dpi=300)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
